# %%
from numpy import array,cos,sin,sqrt
from numpy import loadtxt
import numpy as np
import scipy as sc
import matplotlib.pyplot as plot
from pylab import plot, show,plt
DTS=1.495*10**11
year=1
m=1
GMsol=(4*pow(3.1416,2))
TO=year/DTS
deltaT=0.02
n=200
R1=1
v=2*(3.1416)
the=0
En=[]
posX=[]
posY=[]
posR=[]
posTHE=[]
def aceeee(r):
    return -GMsol/(r*r*r)
def energia(r):
    return -(GMsol*m)/(2*r)
XN=R1
YN=0
VX=0
VY=v
RN=sqrt(XN*XN+YN*YN)
th=0
En.append(energia(RN))
posX.append(XN)
posY.append(YN)
posR.append(RN)
posTHE.append(th)
for i in range (0,n):
    tx=XN
    ty=YN
    tTHE=th
    VX=VX+tx*aceeee(RN)*deltaT
    VY=VY+ty*aceeee(RN)*deltaT
    XN=tx+VX*deltaT
    YN=ty+VY*deltaT
    RN= sqrt(XN*XN + YN*YN)
    th = tTHE+(sqrt(VX*VX + VY*VY)/RN)*deltaT
    En.append(energia(RN))
    posX.append(XN)
    posY.append(YN)
    posR.append(RN)
    posTHE.append(th)
plt.plot(posX,posY,'o')

# %%
plt.polar(posTHE,posR,'o')
plt.show()
plt.plot(En)
plt.show()

# %%
from numpy import array,cos,sin,sqrt
from numpy import loadtxt
import numpy as np
import scipy as sc
import matplotlib.pyplot as plot
from pylab import plot, show,plt
DTS=1.495*10**11
year=1
m=1
GMsol=(4*pow(3.1416,2))
TO=year/DTS
deltaT=0.02
n=200
R1=1
v=2*(3.1416)
the=0
En=[]
posX=[]
posY=[]
posR=[]
posTHE=[]
def aceeee(r):
    return -GMsol/(r*r*r)
def energia(r):
    return -(GMsol*m)/(2*r)
XN=R1
YN=0
VX=0
VY=v
RN=sqrt(XN*XN+YN*YN)
th=0
En.append(energia(RN))
posX.append(XN)
posY.append(YN)
posR.append(RN)
posTHE.append(th)
for i in range (0,n):
    tx=XN
    ty=YN
    tTHE=th
    XN=tx+VX*deltaT
    YN=ty+VY*deltaT
    VX=VX+tx*aceeee(RN)*deltaT
    VY=VY+ty*aceeee(RN)*deltaT
    RN= sqrt(XN*XN + YN*YN)
    th = tTHE+(sqrt(VX*VX + VY*VY)/RN)*deltaT
    En.append(energia(RN))
    posX.append(XN)
    posY.append(YN)
    posR.append(RN)
    posTHE.append(th)
plt.plot(posX,posY,'o')
